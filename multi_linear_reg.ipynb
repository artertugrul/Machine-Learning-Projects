# %% [markdown]
# ##  Rent Prection with Simple Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
streeteasy = pd.read_csv("https://raw.githubusercontent.com/sonnynomnom/Codecademy-Machine-Learning-Fundamentals/master/StreetEasy/manhattan.csv")
#

# %%
df = pd.DataFrame(streeteasy)

# %%
x =df[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway',
      'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck',
      'has_washer_dryer', 'has_doorman', 'has_elevator'
      , 'has_dishwasher', 'has_patio', 'has_gym'  
         ]]
y = df['rent']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size= 0.8, test_size= 0.2, random_state= 6)

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)

y_predict = mlr.predict(x_test)

# %%
plt.scatter(y_test, y_predict, alpha=0.2)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Actual Rent vs Predicted Rent")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_predict)
# Out:
# 0.8050371975357623

# %%
sonny_apartment = [[1, 1, 620, 16, 1, 98, 1, 0, 1, 0, 0, 1, 1, 0]]
predict = mlr.predict(sonny_apartment)

print("Predicted rent: $%.2f" % predict)
# Out:
# Predicted rent: $2393.58
# c:\Users\komur\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
